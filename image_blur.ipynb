# %%
from PIL import Image
from PIL import Image
import numpy as np

# Specify the path to the image file
image_path = "Mauro Lab pic_1 copy.jpg"

# Open the image file
image = Image.open(image_path)

# Convert the image to an array
image_array = np.array(image)

N = 9
blur_filter = 1/(N**2) * np.ones((N,N))

# Apply the filter to the image array
blurred_image_array = np.zeros(image_array.shape)
for i in range(3):
    blurred_image_array[:,:,i] = np.convolve(image_array[:,:,i], blur_filter, mode='same')

# Convert the array to an image
blurred_image = Image.fromarray(np.uint8(blurred_image_array))

blurred_image.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 20
#      18 blurred_image_array = np.zeros(image_array.shape)
#      19 for i in range(3):
# ---> 20     blurred_image_array[:,:,i] = np.convolve(image_array[:,:,i], blur_filter, mode='same')
#      22 # Convert the array to an image
#      23 blurred_image = Image.fromarray(np.uint8(blurred_image_array))
#
# File /opt/homebrew/lib/python3.11/site-packages/numpy/core/numeric.py:834, in convolve(a, v, mode)
#     832 if len(v) == 0:
#     833     raise ValueError('v cannot be empty')
# --> 834 return multiarray.correlate(a, v[::-1], mode)
#
# ValueError: object too deep for desired array
